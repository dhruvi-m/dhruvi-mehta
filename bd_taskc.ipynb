# %% [markdown]
# <a href="https://colab.research.google.com/github/dhruvi-m/dhruvi-mehta/blob/main/bd_taskc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Big Data Assignment(1) task-c
# ## Mehta Dhruvi
# ## 202318003

# %%
# !pip install requests
# !pip install html5lib
# !pip install bs4

# %%
from bs4 import BeautifulSoup

# %%
import pandas as pd

# %%
url="https://www.amazon.in/s?k=phone"

# %%
header = {'user-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36'}

# %%
import requests

# %%
webpage = requests.get (url, headers = header)

# %%
data=webpage.content

# %%
file=open("amzon_data.html","wb")

# %%
file.write(data)
# Out:
# 853665

# %%
file.close()

# %%
file=open("amzon_data.txt","wb")
file.write(data)
file.close()

# %%
webpage
# Out:
# <Response [200]>

# %%
type(webpage.content)
# Out:
# bytes

# %%
soup= BeautifulSoup(webpage.content,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html class="a-no-js" data-19ax5a9jf="dingo" lang="en-in"><!-- sp:feature:head-start -->
# <head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/>
# <!-- sp:end-feature:head-start -->
# <!-- sp:feature:csm:head-open-part1 -->
# <script type="text/javascript">var ue_t0=ue_t0||+new Date();</script>
# <!-- sp:end-feature:csm:head-open-part1 -->
# <!-- sp:feature:cs-optimization -->
# <meta content="on" http-equiv="x-dns-prefetch-control"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://images-eu.ssl-images-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://m.media-amazon.com" rel="preconnect"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="dns-prefetch"/>
# <link crossorigin="" href="https://completion.amazon.com" rel="preconnect"/>
# ...

# %%
links=soup.find_all('span',class_="a-size-medium a-color-base a-text-normal")

# %%
links
# Out:
# [<span class="a-size-medium a-color-base a-text-normal">Redmi A2 (Aqua Blue, 2GB RAM, 64GB Storage)</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Redmi 12 5G Moonstone Silver 8GB RAM 256GB ROM</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Redmi 13C (Stardust Black, 6GB RAM, 128GB Storage) | Powered by 4G MediaTek Helio G85 | 90Hz Display | 50MP AI Triple Camera</span>,
#  <span class="a-size-medium a-color-base a-text-normal">TECNO POP 8 (Mystery White,(8GB*+64GB)|90Hz Punch Hole Display with Dynamic Port &amp; Dual Speakers with DTS| 5000mAh Battery |10W Type-C| Side Fingerprint Sensor| Octa-Core Processor</span>,
#  <span class="a-size-medium a-color-base a-text-normal">Nokia 2660 Flip 4G Volte keypad Phone with Dual SIM, Dual Screen, inbuilt MP3 Player &amp; Wireless FM Radio | Black</span>,
# ...

# %%
product_names=[tag.text.strip() for tag in links]

# %%
for name in product_names:
  print(name)
# Out:
# Redmi A2 (Aqua Blue, 2GB RAM, 64GB Storage)
# Redmi 12 5G Moonstone Silver 8GB RAM 256GB ROM
# Redmi 13C (Stardust Black, 6GB RAM, 128GB Storage) | Powered by 4G MediaTek Helio G85 | 90Hz Display | 50MP AI Triple Camera
# TECNO POP 8 (Mystery White,(8GB*+64GB)|90Hz Punch Hole Display with Dynamic Port & Dual Speakers with DTS| 5000mAh Battery |10W Type-C| Side Fingerprint Sensor| Octa-Core Processor
# Nokia 2660 Flip 4G Volte keypad Phone with Dual SIM, Dual Screen, inbuilt MP3 Player & Wireless FM Radio | Black
# realme narzo N53 (Feather Black, 8GB+128GB) 33W Segment Fastest Charging | Slimmest Phone in Segment | 90 Hz Smooth Display
# Redmi Note 13 5G (Arctic White, 8GB RAM, 256GB Storage) | MTK Dimensity 6080 5G | 7.6mm, Slimmest Note Ever
# realme narzo N53 (Feather Gold, 8GB+128GB) 33W Segment Fastest Charging | Slimmest Phone in Segment | 90 Hz Smooth Display
# ...

# %%
links1=soup.find_all('span',class_="a-price-whole")

# %%
product_names1=[tag.text.strip() for tag in links1]

# %%
  for name1 in product_names1:
  print(name1)
# Out:
# 5,299
# 14,999
# 9,999
# 6,499
# 4,249
# 9,999
# 19,999
# 9,999
# 7,999
# 12,499
# 19,999
# 8,999
# 9,999
# 5,999
# 5,299
# 5,299
# 8,999
# 1,089

# %%
<i class="a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom"><span class="a-icon-alt">4.5 out of 5 stars</span></i>

# %%
links3=soup.find_all('i',class_="a-icon-star-small")

# %%
links3
# Out:
# [<i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">3.9 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4-5 aok-align-bottom"><span class="a-icon-alt">4.4 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">3.9 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-4 aok-align-bottom"><span class="a-icon-alt">4.0 out of 5 stars</span></i>,
#  <i class="a-icon a-icon-star-small a-star-small-3 aok-align-bottom"><span class="a-icon-alt">3.0 out of 5 stars</span></i>,
# ...

# %%
product_rate=[tag.text.strip() for tag in links3]

# %%
for rate in product_rate:
  print(rate)
# Out:
# 3.9 out of 5 stars
# 4.0 out of 5 stars
# 4.0 out of 5 stars
# 4.4 out of 5 stars
# 3.9 out of 5 stars
# 4.0 out of 5 stars
# 3.0 out of 5 stars
# 4.0 out of 5 stars
# 3.9 out of 5 stars
# 4.1 out of 5 stars
# 4.2 out of 5 stars
# 4.0 out of 5 stars
# 4.1 out of 5 stars
# 3.5 out of 5 stars
# 3.9 out of 5 stars
# 3.9 out of 5 stars
# 3.4 out of 5 stars
# 4.2 out of 5 stars

# %%
df= pd.DataFrame({'Name': product_names,
                'price': product_names1,
                 'rate': product_rate
                 })

# %%
df
# Out:
#                                                  Name   price  \
# 0         Redmi A2 (Aqua Blue, 2GB RAM, 64GB Storage)   5,299
# 1      Redmi 12 5G Moonstone Silver 8GB RAM 256GB ROM  14,999
# 2   Redmi 13C (Stardust Black, 6GB RAM, 128GB Stor...   9,999
# 3   TECNO POP 8 (Mystery White,(8GB*+64GB)|90Hz Pu...   6,499
# 4   Nokia 2660 Flip 4G Volte keypad Phone with Dua...   4,249
# 5   realme narzo N53 (Feather Black, 8GB+128GB) 33...   9,999
# 6   Redmi Note 13 5G (Arctic White, 8GB RAM, 256GB...  19,999
# 7   realme narzo N53 (Feather Gold, 8GB+128GB) 33W...   9,999
# 8   Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB St...   7,999
# 9   realme narzo 60X 5G（Nebula Purple 6GB,128GB St...  12,499
# 10  OnePlus Nord CE 2 5G (Bahamas Blue, 8GB RAM, 1...  19,999
# 11  Redmi 13C (Starfrost White, 4GB RAM, 128GB Sto...   8,999
# 12  realme narzo N55 (Prime Black, 6GB+128GB) 33W ...   9,999
# 13     POCO C51 (Power Black, 6GB RAM, 128GB Storage)   5,999
# ...

# %%
df.to_csv('phone.csv',index=False)

# %%
df1 = pd.read_csv('phone.csv')

# %%
df1
# Out:
#                                                  Name   price  \
# 0         Redmi A2 (Aqua Blue, 2GB RAM, 64GB Storage)   5,299
# 1      Redmi 12 5G Moonstone Silver 8GB RAM 256GB ROM  14,999
# 2   Redmi 13C (Stardust Black, 6GB RAM, 128GB Stor...   9,999
# 3   TECNO POP 8 (Mystery White,(8GB*+64GB)|90Hz Pu...   6,499
# 4   Nokia 2660 Flip 4G Volte keypad Phone with Dua...   4,249
# 5   realme narzo N53 (Feather Black, 8GB+128GB) 33...   9,999
# 6   Redmi Note 13 5G (Arctic White, 8GB RAM, 256GB...  19,999
# 7   realme narzo N53 (Feather Gold, 8GB+128GB) 33W...   9,999
# 8   Samsung Galaxy M04 Dark Blue, 4GB RAM, 64GB St...   7,999
# 9   realme narzo 60X 5G（Nebula Purple 6GB,128GB St...  12,499
# 10  OnePlus Nord CE 2 5G (Bahamas Blue, 8GB RAM, 1...  19,999
# 11  Redmi 13C (Starfrost White, 4GB RAM, 128GB Sto...   8,999
# 12  realme narzo N55 (Prime Black, 6GB+128GB) 33W ...   9,999
# 13     POCO C51 (Power Black, 6GB RAM, 128GB Storage)   5,999
# ...
